# %%
import os
print("=== /kaggle/input/datasets/paultimothymooney/ 下的内容 ===")
print(os.listdir("/kaggle/input/datasets/paultimothymooney/"))
# Out:
# === /kaggle/input/datasets/paultimothymooney/ 下的内容 ===
# ['chest-xray-pneumonia']

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import random

# ====================== 固定随机种子（适配TF2.x） ======================
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)

# ====================== 【关键】适配你的路径 ======================
BASE_DIR = "/kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/"
TRAIN_DIR = os.path.join(BASE_DIR, "train")
TEST_DIR = os.path.join(BASE_DIR, "test")

# 路径检查
print(f"✅ TRAIN_DIR 路径：{TRAIN_DIR}")
print(f"✅ TRAIN_DIR 是否存在：{os.path.exists(TRAIN_DIR)}")
print(f"✅ TEST_DIR 是否存在：{os.path.exists(TEST_DIR)}")

# ====================== 超参数设置 ======================
IMG_SIZE = 150
BATCH_SIZE = 32
EPOCHS = 15
LR = 1e-4

# ====================== 数据增强 + 8:2 划分验证集（符合作业要求） ======================
# 训练集增强（防止过拟合）
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.2  # 从train里分20%做验证集，不用原始val文件夹
)

# 训练集
train_generator = datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="binary",
    subset="training",
    shuffle=True
)

# 验证集（从train划分，而非原始val）
val_generator = datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="binary",
    subset="validation",
    shuffle=True
)

# 测试集
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="binary",
    shuffle=False
)

# ====================== 构建CNN模型 ======================
model = Sequential([
    Conv2D(32, (3,3), activation="relu", input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    
    Conv2D(64, (3,3), activation="relu"),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    
    Conv2D(128, (3,3), activation="relu"),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    
    Conv2D(128, (3,3), activation="relu"),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    
    Flatten(),
    Dropout(0.5),
    Dense(256, activation="relu"),
    Dense(1, activation="sigmoid")
])

model.compile(
    optimizer=Adam(learning_rate=LR),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# 模型结构打印
model.summary()

# ====================== 训练模型 ======================
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS,
    verbose=1
)

# ====================== 绘制训练曲线 ======================
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
plt.plot(history.history["accuracy"], label="Train Acc")
plt.plot(history.history["val_accuracy"], label="Val Acc")
plt.title("Accuracy Curve")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.title("Loss Curve")
plt.legend()

plt.tight_layout()
plt.savefig("/kaggle/working/train_curve.png", dpi=300)
plt.show()

# ====================== 测试集评估（四项核心指标） ======================
y_true = test_generator.classes
y_pred = model.predict(test_generator)
y_pred = (y_pred > 0.5).astype(int).flatten()

acc = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print("\n===== 测试集最终指标 =====")
print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall:    {recall:.4f}")
print(f"F1 Score:  {f1:.4f}")

print("\n分类报告：")
print(classification_report(y_true, y_pred, target_names=["Normal", "Pneumonia"]))

# ====================== 绘制混淆矩阵 ======================
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
            xticklabels=["Normal", "Pneumonia"], 
            yticklabels=["Normal", "Pneumonia"])
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.savefig("/kaggle/working/confusion_matrix.png", dpi=300)
plt.show()
# Out:
# 2026-05-10 08:15:58.605052: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778400958.786063      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778400958.838060      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778400959.269305      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778400959.269351      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778400959.269354      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778400959.269357      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ✅ TRAIN_DIR 路径：/kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray/train
# ✅ TRAIN_DIR 是否存在：True
# ✅ TEST_DIR 是否存在：True
# Found 4173 images belonging to 2 classes.
# Found 1043 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2026-05-10 08:16:26.659631: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 148, 148, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 72, 72, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 34, 34, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 15, 15, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 15, 15, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,605,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,848,385 (7.05 MB)
#  Trainable params: 1,847,681 (7.05 MB)
#  Non-trainable params: 704 (2.75 KB)
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 215s 2s/step - accuracy: 0.8413 - loss: 0.4208 - val_accuracy: 0.7430 - val_loss: 1.9766
# Epoch 2/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 205s 2s/step - accuracy: 0.9188 - loss: 0.2088 - val_accuracy: 0.7430 - val_loss: 3.4007
# Epoch 3/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 204s 2s/step - accuracy: 0.9423 - loss: 0.1548 - val_accuracy: 0.7430 - val_loss: 3.2803
# Epoch 4/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 206s 2s/step - accuracy: 0.9419 - loss: 0.1566 - val_accuracy: 0.7430 - val_loss: 2.3180
# Epoch 5/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 204s 2s/step - accuracy: 0.9423 - loss: 0.1442 - val_accuracy: 0.8236 - val_loss: 0.4717
# Epoch 6/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 206s 2s/step - accuracy: 0.9538 - loss: 0.1205 - val_accuracy: 0.9540 - val_loss: 0.1097
# Epoch 7/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 205s 2s/step - accuracy: 0.9501 - loss: 0.1291 - val_accuracy: 0.9108 - val_loss: 0.2349
# Epoch 8/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 207s 2s/step - accuracy: 0.9576 - loss: 0.1049 - val_accuracy: 0.7689 - val_loss: 0.5006
# Epoch 9/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 207s 2s/step - accuracy: 0.9610 - loss: 0.1212 - val_accuracy: 0.9674 - val_loss: 0.0902
# Epoch 10/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 226s 2s/step - accuracy: 0.9628 - loss: 0.0971 - val_accuracy: 0.9511 - val_loss: 0.1023
# Epoch 11/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 206s 2s/step - accuracy: 0.9604 - loss: 0.1033 - val_accuracy: 0.9156 - val_loss: 0.1719
# Epoch 12/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 206s 2s/step - accuracy: 0.9662 - loss: 0.0943 - val_accuracy: 0.9674 - val_loss: 0.0888
# Epoch 13/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 207s 2s/step - accuracy: 0.9729 - loss: 0.0795 - val_accuracy: 0.7565 - val_loss: 1.3074
# Epoch 14/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 207s 2s/step - accuracy: 0.9740 - loss: 0.0789 - val_accuracy: 0.8006 - val_loss: 0.7319
# Epoch 15/15
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 209s 2s/step - accuracy: 0.9679 - loss: 0.0850 - val_accuracy: 0.8188 - val_loss: 0.4575
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 13s 637ms/step
#
# ===== 测试集最终指标 =====
# Accuracy:  0.7788
# Precision: 0.9809
# Recall:    0.6590
# F1 Score:  0.7883
#
# 分类报告：
#               precision    recall  f1-score   support
#
#       Normal       0.63      0.98      0.77       234
#    Pneumonia       0.98      0.66      0.79       390
#
#     accuracy                           0.78       624
#    macro avg       0.81      0.82      0.78       624
# weighted avg       0.85      0.78      0.78       624

# %%
# ==========================
# 肺炎三分类：NORMAL / VIRAL / BACTERIAL
# 加分项专用 · 直接运行
# ==========================

import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from PIL import Image

# 屏蔽警告
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# ====================== 路径（自动适配你的 Kaggle） ======================
BASE_PATH = "/kaggle/input/datasets/paultimothymooney/chest-xray-pneumonia/chest_xray"
TRAIN_PATH = os.path.join(BASE_PATH, "train")
TEST_PATH = os.path.join(BASE_PATH, "test")

# ====================== 工具：根据文件名自动打三分类标签 ======================
def get_label(filename):
    if "NORMAL" in filename:
        return 0   # 正常
    elif "virus" in filename:
        return 1  # 病毒肺炎
    elif "bacteria" in filename:
        return 2  # 细菌肺炎
    else:
        return -1

# ====================== 加载图片 + 自动三分类 ======================
def load_data(path):
    images = []
    labels = []
    for folder in ["NORMAL", "PNEUMONIA"]:
        folder_path = os.path.join(path, folder)
        for img_name in os.listdir(folder_path):
            img_path = os.path.join(folder_path, img_name)
            try:
                img = Image.open(img_path).convert("RGB")
                img = img.resize((150, 150))
                img = np.array(img) / 255.0
                label = get_label(img_name)
                if label != -1:
                    images.append(img)
                    labels.append(label)
            except:
                continue
    return np.array(images), np.array(labels)

# 加载数据
print("正在加载训练数据...")
X_train, y_train = load_data(TRAIN_PATH)
print("正在加载测试数据...")
X_test, y_test = load_data(TEST_PATH)

# 独热编码
y_train = to_categorical(y_train, num_classes=3)
y_test = to_categorical(y_test, num_classes=3)

# ====================== 构建三分类模型 ======================
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    
    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    
    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),
    
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')  # 3分类
])

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# ====================== 训练 ======================
history = model.fit(
    X_train, y_train,
    batch_size=32,
    epochs=12,
    validation_split=0.2,
    verbose=1
)

# ====================== 评估 ======================
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

acc = accuracy_score(y_true_classes, y_pred_classes)
print("\n===== 三分类测试集准确率 =====")
print(f"Accuracy: {acc:.4f}")

print("\n分类报告：")
print(classification_report(
    y_true_classes, y_pred_classes,
    target_names=["Normal", "Viral", "Bacterial"]
))

# ====================== 混淆矩阵 ======================
cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(7,5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=["Normal","Viral","Bacterial"],
            yticklabels=["Normal","Viral","Bacterial"])
plt.title('Three-Class Confusion Matrix')
plt.xlabel('Pred')
plt.ylabel('True')
plt.savefig("/kaggle/working/3class_cm.png", dpi=300)
plt.show()

# ====================== 训练曲线 ======================
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.savefig("/kaggle/working/3class_curve.png", dpi=300)
plt.show()
# Out:
# 正在加载训练数据...
# 正在加载测试数据...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.6197 - loss: 1.3873 - val_accuracy: 0.3344 - val_loss: 0.8160
# Epoch 2/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.7539 - loss: 0.5597 - val_accuracy: 0.3355 - val_loss: 1.1554
# Epoch 3/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.7831 - loss: 0.4962 - val_accuracy: 0.6786 - val_loss: 0.6112
# Epoch 4/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.8000 - loss: 0.4565 - val_accuracy: 0.7478 - val_loss: 0.5340
# Epoch 5/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.8227 - loss: 0.4262 - val_accuracy: 0.7457 - val_loss: 0.5699
# Epoch 6/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.8309 - loss: 0.3917 - val_accuracy: 0.7652 - val_loss: 0.5164
# Epoch 7/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.8339 - loss: 0.3694 - val_accuracy: 0.7532 - val_loss: 0.5453
# Epoch 8/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.8548 - loss: 0.3245 - val_accuracy: 0.7673 - val_loss: 0.5274
# Epoch 9/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.8734 - loss: 0.2951 - val_accuracy: 0.7576 - val_loss: 0.5365
# Epoch 10/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.8976 - loss: 0.2424 - val_accuracy: 0.7392 - val_loss: 0.5837
# Epoch 11/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 154s 1s/step - accuracy: 0.9130 - loss: 0.2159 - val_accuracy: 0.7565 - val_loss: 0.5559
# Epoch 12/12
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.9249 - loss: 0.1993 - val_accuracy: 0.7446 - val_loss: 0.6160
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 4s 233ms/step
#
# ===== 三分类测试集准确率 =====
# Accuracy: 0.7063
#
# 分类报告：
#               precision    recall  f1-score   support
#
#       Normal       0.93      0.38      0.54       165
#        Viral       0.55      0.72      0.63       148
#    Bacterial       0.75      0.92      0.83       242
#
#     accuracy                           0.71       555
#    macro avg       0.74      0.67      0.67       555
# weighted avg       0.75      0.71      0.69       555
